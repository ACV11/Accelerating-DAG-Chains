# %%
import numpy as np
import matplotlib.pyplot as plt
from MCMU import NewGraphStructure

plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

# %%
plt.figure(figsize=(25, 10))
t = NewGraphStructure(nodeArrivalSpeed=10)
for i in range(10):
    t.GetNextNode()
t.plotgrp()
